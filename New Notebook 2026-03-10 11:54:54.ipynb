# %%
ls=list(input("enter the values for the list"))
counts={}
for l in ls:
    if l in counts:
        counts[l]+=1
    else:
        counts[l]=1
for element,count in counts.items():
    print(element,":",count)
